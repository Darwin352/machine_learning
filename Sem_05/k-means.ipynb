# %% [markdown]
# # K Means - Generated data
#
# Isotropic dataset module in sklearn [here](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_blobs.html) \
# Train-test splits in sklearn [here](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html) \
# k-Means module in sklearn [here](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split

# %%
_, axes = plt.subplots(1,2, figsize=(10,5))

X,_ = make_blobs(n_samples = 1000 , random_state = 170 )

# Create train (80%) and test (20%) sets and print all shapes
X_train,X_test=train_test_split(X , test_size=0.2,random_state=1)
print (X.shape,X_train.shape,X_test.shape)
axes[0].scatter( X[:,0],X[:,1] , edgecolors='k', cmap='spring')
axes[1].scatter(X_train[:,0],X_train[:,1],c='r',edgecolor='k')
axes[1].scatter(X_test[:,0],X_test[:,1],c='b',edgecolor='k')
# Out:
# (1000, 2) (800, 2) (200, 2)
# <ipython-input-9-12e9cecce184>:8: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   axes[0].scatter( X[:,0],X[:,1] , edgecolors='k', cmap='spring')

# %%
kmeans = KMeans(n_clusters=4, random_state=1)

# Train Kmeans
kmeans.fit(X_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=4, random_state=1)

# %%
# Plot centroids
centroids = kmeans.cluster_centers_
labels=kmeans.labels_
print(centroids,labels.shape)
# Out:
# [[-5.31685508  0.07660993]
#  [ 1.977576    0.58342484]
#  [-8.87412543 -5.47153454]
#  [-3.64535147 -0.15009683]] (800,)

# %%
# Create predictions
predictions = kmeans.predict(X_test)
print(predictions.shape)
# Out:
# (200,)

# %%
_, axes = plt.subplots (1,2,figsize = (8,4))
colors=['blue','cyan','magenta']

# plot data and found centroids
axes[0].scatter(X_test[:,0],X_test[:,1],c='y',edgecolor='k',alpha=0.5)
axes[0].scatter(centroids[:,0],centroids[:,1],c='r',s=500,marker='*',linewidths=1)
axes[1].scatter(X_test[:,0],X_test[:,1],c=predictions,edgecolor='k',cmap='spring')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %run "/content/drive/MyDrive/Repositorio/machine_learning/Fun_Lp.ipynb"

# %%
# Plot decision boundaries

# %% [markdown]
# # K Means - Real data
#
# Download the fruits data [here](https://drive.google.com/file/d/1M8tiAWDZclABJN1Meq9oEHCLJTNyHdpP/view?usp=share_link)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
data =
X = _
Y = _

# %%
# Split train / test data

# %%
# Train Kmeans
kmeans =

# %%
centroids = _
print(centroids)

# %%
# Predict values
predictions =

# %%
_, axes = plt.subplots (1,2, figsize = (15,5))
colores=['blue','cyan','magenta']

# %%
# Plot decision boundaries
_

# %% [markdown]
# # Expanding clustering
#
# Explore K-means using different num of centroids

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
data = _
X = _
Y = _
